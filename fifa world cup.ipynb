# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("f.csv")

# %%
df
# Out:
#       player_id       player_name  age nationality   team  jersey_number  \
# 0        P00055        Rodri Fati   26     Spanish  Spain              3
# 1        P00070   Ansu Le Normand   19     Spanish  Spain             18
# 2        P00066        Gavi Ramos   18     Spanish  Spain             14
# 3        P00073     Pedro Cubarsi   20     Spanish  Spain             21
# 4        P00059  Alvaro Oyarzabal   23     Spanish  Spain              7
# ...         ...               ...  ...         ...    ...            ...
# 54595    P00996       Amir Younis   28       Iraqi   Iraq              8
# 54596    P01006  Safaa Al-Khafaji   20       Iraqi   Iraq             18
# 54597    P01008     Ahmed Hussein   26       Iraqi   Iraq             20
# 54598    P00991     Ibrahim Mhawi   30       Iraqi   Iraq              3
# 54599    P00989  Mohannad Hussein   27       Iraqi   Iraq              1
#
#          position  height_cm  weight_kg preferred_foot  ... possession_impact  \
# ...

# %%
plt.plot(df["player_name"],df["team"])

# %%
plt.plot(df["player_name"],df["team"])
plt.title("title")
plt.xlabel("player_name")
plt.ylabel("team")
plt.show()

# %%
df['age'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['age'].value_counts().plot(kind='box')
# Out:
# <Axes: >

# %%
df['age'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='age'>

# %%
df['age'].value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='age'>

# %%
df['team'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['team'].value_counts().plot(kind='box')
# Out:
# <Axes: >

# %%
df['team'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='team'>

# %%
df['team'].value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='team'>

# %%
df['position'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['position'].value_counts().plot(kind='box')
# Out:
# <Axes: >

# %%
df['position'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='position'>

# %%
df['position'].value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='position'>

# %%
df['player_name'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['player_name'].value_counts().plot(kind='box')
# Out:
# <Axes: >

# %%
df['player_name'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='player_name'>

# %%
df['player_name'].value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='player_name'>

# %%
df['height_cm'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['height_cm'].value_counts().plot(kind='box')
# Out:
# <Axes: >

# %%
df['height_cm'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='height_cm'>

# %%
df['height_cm'].value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='height_cm'>

# %%
df['height_cm'].value_counts().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind='scatter',
x='position',y='team')
# Out:
# <Axes: xlabel='position', ylabel='team'>

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
sns.countplot(x='age', data=df)
# Out:
# <Axes: xlabel='age', ylabel='count'>
